# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('..\\data\\data_preprocessing.csv')

# %%
df.head()
# Out:
#    gender  age education currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0    male   39   level 4            No         0.0     No              No
# 1  female   46   level 2            No         0.0     No              No
# 2    male   48   level 1           Yes        20.0     No              No
# 3  female   61   level 3           Yes        30.0     No              No
# 4  female   46   level 3           Yes        23.0     No              No
#
#   prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0           No       No    195.0  106.0   70.0  26.97       80.0     77.0
# 1           No       No    250.0  121.0   81.0  28.73       95.0     76.0
# 2           No       No    245.0  127.5   80.0  25.34       75.0     70.0
# 3          Yes       No    225.0  150.0   95.0  28.58       65.0    103.0
# 4           No       No    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD  ratio_pression
# 0           0        1.514286
# 1           0        1.493827
# 2           0        1.593750
# 3           1        1.578947
# 4           0        1.547619

# %%
df.shape
# Out:
# (4082, 17)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD', 'ratio_pression'],
#       dtype='object')

# %%
df['education'] = df['education'].replace({'level 1' : 1, 'level 2' : 2, 'level 3' : 3, 'level 4' : 4})

# %%
colonne_categorielles = df.select_dtypes(include = "object").columns
for col in colonne_categorielles :
    df[col] = df[col].replace({"No" : 0, "Yes" : 1})

df["gender"] = df["gender"].replace({"male" : 1, "female" : 0})

# %%
df.head()
# Out:
#    gender  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0       1   39          4              0         0.0       0                0
# 1       0   46          2              0         0.0       0                0
# 2       1   48          1              1        20.0       0                0
# 3       0   61          3              1        30.0       0                0
# 4       0   46          3              1        23.0       0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD  ratio_pression
# 0           0        1.514286
# 1           0        1.493827
# 2           0        1.593750
# 3           1        1.578947
# 4           0        1.547619

# %%
cor = df.corr()
plt.figure(figsize = (15, 15))
sns.heatmap(cor, annot = True, cmap = "coolwarm")
plt.show()

# %%
df["ratio_smoker_cig"] = df['cigsPerDay'] * df['currentSmoker']

# %%
cor = df.corr()
plt.figure(figsize = (15, 15))
sns.heatmap(cor, annot = True, cmap = "coolwarm")
plt.show()

# %% [markdown]
# # Divisions du jeu de donnee

# %%
X = df.drop('TenYearCHD', axis = 1)
y = df['TenYearCHD']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state = 42, test_size = 0.2)

# %%
y_train.value_counts()
# Out:
# TenYearCHD
# 0    2771
# 1     494
# Name: count, dtype: int64

# %%
lg = LogisticRegression()

lg.fit(X_train, y_train)
y_pred = lg.predict(X_train)
